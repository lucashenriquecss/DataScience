# %%
import pandas as pd

avaliacoes = pd.read_csv('ratings.csv')
avaliacoes.head() #Lendo o arquivo e filtrando para os 5 primeiros
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
avaliacoes.shape
#mostra a quantidade de colunas e itens
# Out:
# (100836, 4)

# %%
avaliacoes.columns = ['usuarioID', 'filmesID', 'nota','momento']# Fazendo alteração de cabeçalho
avaliacoes.head() #
# Out:
#    usuarioID  filmesID  nota    momento
# 0          1         1   4.0  964982703
# 1          1         3   4.0  964981247
# 2          1         6   4.0  964982224
# 3          1        47   5.0  964983815
# 4          1        50   5.0  964982931

# %%
avaliacoes['nota'].unique() #filtrando as notas
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
avaliacoes['nota'].value_counts() # quantidade de vezes que a nota aparece
# Out:
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: nota, dtype: int64

# %%
print(avaliacoes['nota'].mean()) #media
print(avaliacoes['nota'].median()) #mediana
# Out:
# 3.501556983616962
# 3.5

# %%
avaliacoes.nota.plot()

# %%
avaliacoes.nota.plot(kind='hist')

# %%
avaliacoes.nota.describe()#descrição
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: nota, dtype: float64

# %%
import seaborn as sns
sns.boxplot(avaliacoes.nota) #mostra a descriçao em grafico, onde a maioria das avaliaçoes estao entre 3 e 4
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import pandas as pd
filmes = pd.read_csv("movies.csv")
filmes.columns=["filmesID","titulo", "generos"]
filmes.head()
# Out:
#    filmesID  ...                                      generos
# 0         1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1         2  ...                   Adventure|Children|Fantasy
# 2         3  ...                               Comedy|Romance
# 3         4  ...                         Comedy|Drama|Romance
# 4         5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
avaliacoes.head()
# Out:
#    usuarioID  filmesID  nota    momento
# 0          1         1   4.0  964982703
# 1          1         3   4.0  964981247
# 2          1         6   4.0  964982224
# 3          1        47   5.0  964983815
# 4          1        50   5.0  964982931

# %% [markdown]
# Analisando notas de filmes especificos

# %%
avaliacoes.query("filmesID==1").nota.mean()
# Out:
# 3.4318181818181817

# %%
avaliacoes.groupby("filmesID").mean()
# Out:
#            usuarioID      nota       momento
# filmesID
# 1         306.530233  3.920930  1.129835e+09
# 2         329.554545  3.431818  1.135805e+09
# 3         283.596154  3.259615  1.005110e+09
# 4         219.857143  2.357143  8.985789e+08
# 5         299.571429  3.071429  9.926643e+08
# ...              ...       ...           ...
# 193581    184.000000  4.000000  1.537109e+09
# 193583    184.000000  3.500000  1.537110e+09
# 193585    184.000000  3.500000  1.537110e+09
# 193587    184.000000  3.500000  1.537110e+09
# 193609    331.000000  4.000000  1.537158e+09
#
# [9724 rows x 3 columns]

# %%
media = avaliacoes.groupby("filmesID").mean()['nota'].round(2) #medias por filme
media
# Out:
# filmesID
# 1         3.92
# 2         3.43
# 3         3.26
# 4         2.36
# 5         3.07
#           ...
# 193581    4.00
# 193583    3.50
# 193585    3.50
# 193587    3.50
# 193609    4.00
# Name: nota, Length: 9724, dtype: float64

# %%
media.plot(kind='hist')

# %%
sns.boxplot(media)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
media.describe().round(2)
# Out:
# count    9724.00
# mean        3.26
# std         0.87
# min         0.50
# 25%         2.80
# 50%         3.42
# 75%         3.91
# max         5.00
# Name: nota, dtype: float64

# %%
sns.distplot(media)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
